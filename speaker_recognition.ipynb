# %%
# !rsync -av drive/MyDrive/Colab_Notebooks/my_GITHUB_projects/Speaker_Recognition_Tensorflow/ . --exclude=speaker_recognition.ipynb
# !python prepare_to_start_train.py --config ./RA_config.yml --model ResArch
# Out:
# sending incremental file list
# datasets/
# datasets/ResArch_dataset.py
#
# sent 15,886 bytes  received 51 bytes  31,874.00 bytes/sec
# total size is 33,418  speedup is 2.10
# 2021-02-23 12:50:44.418412: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
import os
os.environ['KAGGLE_USERNAME'] = "masoudmzb"
os.environ['KAGGLE_KEY'] = "4dae19325a38899d87ed3aac64e46dfe"
import kaggle


kaggle.api.authenticate()



kaggle.api.dataset_download_files('kongaevans/speaker-recognition-dataset', path='./zmagas', unzip=True)

# %%
! rm -rf ahooe
